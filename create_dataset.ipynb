# %%
import os
import re
import sys
import warnings
import numpy as np
import pandas as pd

from playsound import playsound 

from extract_mir import *
warnings.filterwarnings('ignore')

# %% [markdown]
# #  Coleta de dados

# %%
# wget "https://ia802205.us.archive.org/zip_dir.php?path=/8/items/xccoverbl_2014.zip&formats=FLAC"

# %% [markdown]
# # Importar dados

# %%
metadata = pd.read_csv('data/xcmeta.csv', usecols=["id", "species"])
metadata = metadata.rename(columns={'id':'arquivo'})

# %% [markdown]
# # Explorando os nossos dados

# %% [markdown]
# - Arquivos de audio por especie de passaros

# %%
metadata["species"].value_counts()
# Out:
# palustris       6
# major           6
# montanus        6
# megarhynchos    3
# apiaster        3
#                ..
# martius         3
# urbicum         3
# caeruleus       3
# canorus         3
# vanellus        3
# Name: species, Length: 85, dtype: int64

# %% [markdown]
# - Reproduzir arquivos

# %%
playsound('sonds/xc164926.flac')

# %% [markdown]
# - Calculo de tempo de duração de cada arquivo de audio

# %%
# time_sonds = []

# for sound in metadata.file_id:

#     y, sr = lr.load(f'sonds/xc{sound}.flac')
#     durantion = get_duration(y, sr)

#     print(durantion)
#     time_sonds.append(round(durantion, 0))
    
# metadata["time"] = time_sonds    
# metadata.to_csv('xcmeta.csv')

# %% [markdown]
# # Feature Engineer

# %% [markdown]
# - Extrair e armazenar features de audio

# %%
extract_features("sonds/", "mean")

# %%
df_mir = pd.read_csv('data/features_sonds.csv')

# %%
df_mir
# Out:
#      arquivo     species fourier_tempogram-mean-0  \
# 0     132608     flammea  (251.53309631347656+0j)
# 1     132611     flammea     (259.70166015625+0j)
# 2      35068     flammea  (190.72215270996094+0j)
# 3      82715   palustris  (323.50115966796875+0j)
# 4      64685   palustris   (282.1729736328125+0j)
# ..       ...         ...                      ...
# 259   132392  philomelos  (291.63763427734375+0j)
# 260   146756  philomelos   (268.4815673828125+0j)
# 261    27060    vanellus   (341.1621398925781+0j)
# 262    97982    vanellus   (258.8721008300781+0j)
# 263    69855    vanellus   (291.5044860839844+0j)
#
#                         fourier_tempogram-mean-1  \
# 0      (-125.76673126220703-1.2681530714035034j)
# 1      (-129.85952758789062-3.4507150650024414j)
# 2           (-95.39623260498047-6.514892578125j)
# 3       (-161.74093627929688-7.180373668670654j)
# 4        (-141.0712127685547-4.479115962982178j)
# ..                                           ...
# 259  (-145.81959533691406-0.029156381264328957j)
# 260    (-134.2489471435547-0.12738800048828125j)
# 261    (-170.57742309570312-0.5229384899139404j)
# 262     (-129.43167114257812-0.324832946062088j)
# 263     (-145.74949645996094-1.239804983139038j)
#
#                           fourier_tempogram-mean-2  \
# 0        (0.00612641079351306+0.9206206202507019j)
# 1       (0.023019367828965187+2.1413066387176514j)
# 263      (0.01022718008607626+0.19787189364433289j)
#
#                              fourier_tempogram-mean-7  ... mfcc-mean-19  \
# 0       (-0.0027650517877191305-0.11661908775568008j)  ...     3.678343
# 1         (-0.020403189584612846-0.4313928484916687j)  ...     6.539614
# 2         (-0.039292965084314346-1.3524980545043945j)  ...     3.841586
# 3        (-0.006671360228210688-0.17688553035259247j)  ...     2.818051
# 4         (-0.005907224491238594-0.1529945284128189j)  ...     9.404188
# ..                                                ...  ...          ...
# 259  (-0.00010426356311654672-0.0056689404882490635j)  ...     2.510516
# 260      (-0.01388621050864458+0.021227406337857246j)  ...     0.490833
# 261    (-0.0012009170604869723-0.026055706664919853j)  ...    -3.575015
# 262      (0.0020407065749168396+0.01735490933060646j)  ...    -0.909196
# 263     (-0.005414564162492752+0.012410049326717854j)  ...    -2.319636
#
#     tonnetz-mean-0 tonnetz-mean-1 tonnetz-mean-2 tonnetz-mean-3  \
# 0        -0.006485       0.004259      -0.005751       0.003680
# 1         0.002514      -0.022335      -0.011952       0.058717
# 2         0.004548      -0.009998       0.048268      -0.015490
# 3         0.003534       0.000077       0.016498      -0.007280
# 4         0.005944      -0.007011       0.028142      -0.019186
# ..             ...            ...            ...            ...
# 259       0.012072       0.019389       0.024667       0.007262
# 260       0.006474       0.005587       0.008275      -0.018651
# 261       0.001898      -0.003764      -0.031344      -0.010915
# 262       0.004315       0.000150      -0.007994      -0.022980
# 263      -0.009154      -0.003058       0.004639      -0.016835
#
#     tonnetz-mean-4 tonnetz-mean-5 rms-mean-0 zcr-mean-0 rolloff-mean-0
# 0        -0.002690       0.000009   0.010133   0.156673   10971.990206
# 1         0.016824      -0.005542   0.013791   0.144492   11565.475525
# 2        -0.011625      -0.010950   0.010008   0.236547   11098.715496
# 3        -0.005929      -0.001681   0.015728   0.235209    9576.714957
# 4         0.001500       0.000639   0.011937   0.206531    9820.667665
# ..             ...            ...        ...        ...            ...
# 259       0.010036      -0.001262   0.030607   0.163760    6243.274109
# 260      -0.001811      -0.001125   0.006916   0.143330    6246.110972
# 261      -0.002464      -0.000296   0.007711   0.113148    5100.927231
# 262       0.001628       0.000102   0.010486   0.171336    9325.487130
# 263      -0.000825      -0.003761   0.024721   0.130293    6390.657541
#
# [264 rows x 772 columns]

# %% [markdown]
# - Remover alguns caracteres da coluna arquivos

# %%
list_strings = ["xc", ".flac"]

for string in list_strings: 
    df_mir["arquivo"] = remove_caracter(df_mir.arquivo, string).astype(int)

# %% [markdown]
# - Criando nossas classes

# %%
df_mir = pd.merge(metadata, df_mir, how='left', on="arquivo")

# %% [markdown]
# - Salvar o dataset com os novos ajustes

# %%
df_mir.to_csv('data/features_sonds.csv', index = False)
